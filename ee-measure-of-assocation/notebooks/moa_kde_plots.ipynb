# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from moa import plotting, scores

# %%
df = pd.read_csv('data/raw/samples-124.csv')

# %%
data_1 = df[df['class_name'] == 1]['VH']
data_2 = df[df['class_name'] == 2]['VH']

# %%
# add the first series to the plot
plt.hist(data_1, alpha=0.5, label='Class 1', bins=50)

# add the second series to the plot
plt.hist(data_2, alpha=0.5, label='Class 2', bins=50)

plt.show()
